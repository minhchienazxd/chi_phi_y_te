# %%
pip install seaborn
# Out:
# Collecting seabornNote: you may need to restart the kernel to use updated packages.
#
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\bravo\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.1.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\bravo\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\bravo\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bravo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\bravo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bravo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bravo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\bravo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\bravo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bravo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bravo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bravo\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bravo\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\bravo\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/294.9 kB 1.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 122.9/294.9 kB 1.2 MB/s eta 0:00:01
#    ------------------------ --------------- 184.3/294.9 kB 1.6 MB/s eta 0:00:01
#    ------------------------------- -------- 235.5/294.9 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#import packahes
import pandas as pd 
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols

# %%
# Load dataset
penguins = sns.load_dataset("penguins")

#Examine firts 5 rows of dataset
penguins.head(10)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# 6       3625.0  Female
# 7       4675.0    Male
# 8       3475.0     NaN
# 9       4250.0     NaN

# %%
# Sub X and y variables
penguins_X = penguins[["bill_length_mm","flipper_length_mm"]]
penguins_y = penguins[["body_mass_g"]]

# %%
#Write out OLS formula as a string
ols_formula = "body_mass_g ~ bill_length_mm + flipper_length_mm"

# %%
from statsmodels.formula.api import ols

# %%
ols_data = pd.concat([penguins_X, penguins_y], axis = 1)
OLS = ols(formula = ols_formula, data = ols_data)
model = OLS.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            body_mass_g   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                     536.6
# Date:                Thu, 19 Sep 2024   Prob (F-statistic):          9.09e-106
# Time:                        22:35:57   Log-Likelihood:                -2527.7
# No. Observations:                 342   AIC:                             5061.
# Df Residuals:                     339   BIC:                             5073.
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept         -5736.8972    307.959    -18.629      0.000   -6342.649   -5131.146
# bill_length_mm        6.0475      5.180      1.168      0.244      -4.141      16.236
# flipper_length_mm    48.1449      2.011     23.939      0.000      44.189      52.101
# ==============================================================================
# Omnibus:                        5.475   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.065   Jarque-Bera (JB):                5.408
# Skew:                           0.308   Prob(JB):                       0.0669
# Kurtosis:                       3.025   Cond. No.                     2.98e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.98e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
print(penguins['sex'].unique())
print(penguins['species'].unique())
# Out:
# ['Male' 'Female' nan]
# ['Adelie' 'Chinstrap' 'Gentoo']

# %%
one_hot_encoded_data = pd.get_dummies(penguins, columns = ['sex', 'species'])
print(one_hot_encoded_data)
# Out:
#         island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0    Torgersen            39.1           18.7              181.0       3750.0
# 1    Torgersen            39.5           17.4              186.0       3800.0
# 2    Torgersen            40.3           18.0              195.0       3250.0
# 3    Torgersen             NaN            NaN                NaN          NaN
# 4    Torgersen            36.7           19.3              193.0       3450.0
# ..         ...             ...            ...                ...          ...
# 339     Biscoe             NaN            NaN                NaN          NaN
# 340     Biscoe            46.8           14.3              215.0       4850.0
# 341     Biscoe            50.4           15.7              222.0       5750.0
# 342     Biscoe            45.2           14.8              212.0       5200.0
# 343     Biscoe            49.9           16.1              213.0       5400.0
#
#      sex_Female  sex_Male  species_Adelie  species_Chinstrap  species_Gentoo
# 0         False      True            True              False           False
# 1          True     False            True              False           False
# 2          True     False            True              False           False
# 3         False     False            True              False           False
# 4          True     False            True              False           False
# ..          ...       ...             ...                ...             ...
# 339       False     False           False              False            True
# 340        True     False           False              False            True
# 341       False      True           False              False            True
# 342        True     False           False              False            True
# 343       False      True           False              False            True
#
# [344 rows x 10 columns]

# %%
ols_formulas = "body_mass_g ~ bill_length_mm + flipper_length_mm + sex_Female + sex_Male"

# %%
penguins_X = one_hot_encoded_data[["bill_length_mm", "flipper_length_mm", "sex_Female", "sex_Male"]]
penguins_Y = one_hot_encoded_data[["body_mass_g"]]

# %%
ols_datas = pd.concat([penguins_X, penguins_Y], axis = 1)
OLS = ols(formula = ols_formulas, data = ols_datas)
model = OLS.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            body_mass_g   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     344.9
# Date:                Thu, 19 Sep 2024   Prob (F-statistic):          1.00e-117
# Time:                        22:43:40   Log-Likelihood:                -2493.4
# No. Observations:                 342   AIC:                             4997.
# Df Residuals:                     337   BIC:                             5016.
# Df Model:                           4
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept          -5285.4104    308.339    -17.142      0.000   -5891.922   -4678.899
# sex_Female[T.True]   -61.9025    122.510     -0.505      0.614    -302.882     179.077
# sex_Male[T.True]     298.0199    123.564      2.412      0.016      54.967     541.073
# bill_length_mm        -4.3828      4.859     -0.902      0.368     -13.941       5.176
# flipper_length_mm     47.5979      1.827     26.054      0.000      44.004      51.191
# ==============================================================================
# Omnibus:                        0.541   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.763   Jarque-Bera (JB):                0.658
# Skew:                           0.076   Prob(JB):                        0.720
# Kurtosis:                       2.849   Cond. No.                     3.38e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.38e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
