# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
dfs = sns.load_dataset("penguins",cache=False)

# %%
dfs.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df = dfs[["body_mass_g", "bill_length_mm", "sex", "species"]]

# %%
df
# Out:
#      body_mass_g  bill_length_mm     sex species
# 0         3750.0            39.1    Male  Adelie
# 1         3800.0            39.5  Female  Adelie
# 2         3250.0            40.3  Female  Adelie
# 3            NaN             NaN     NaN  Adelie
# 4         3450.0            36.7  Female  Adelie
# ..           ...             ...     ...     ...
# 339          NaN             NaN     NaN  Gentoo
# 340       4850.0            46.8  Female  Gentoo
# 341       5750.0            50.4    Male  Gentoo
# 342       5200.0            45.2  Female  Gentoo
# 343       5400.0            49.9    Male  Gentoo
#
# [344 rows x 4 columns]

# %%
df.columns = ["body_mass_g", "bill_length_mm", "gender", "species"]

# %%
df
# Out:
#      body_mass_g  bill_length_mm  gender species
# 0         3750.0            39.1    Male  Adelie
# 1         3800.0            39.5  Female  Adelie
# 2         3250.0            40.3  Female  Adelie
# 3            NaN             NaN     NaN  Adelie
# 4         3450.0            36.7  Female  Adelie
# ..           ...             ...     ...     ...
# 339          NaN             NaN     NaN  Gentoo
# 340       4850.0            46.8  Female  Gentoo
# 341       5750.0            50.4    Male  Gentoo
# 342       5200.0            45.2  Female  Gentoo
# 343       5400.0            49.9    Male  Gentoo
#
# [344 rows x 4 columns]

# %%
df.dropna(inplace=True)

# %%
df.reset_index(inplace=True, drop=True)

# %%
df
# Out:
#      body_mass_g  bill_length_mm  gender species
# 0         3750.0            39.1    Male  Adelie
# 1         3800.0            39.5  Female  Adelie
# 2         3250.0            40.3  Female  Adelie
# 3         3450.0            36.7  Female  Adelie
# 4         3650.0            39.3    Male  Adelie
# ..           ...             ...     ...     ...
# 328       4925.0            47.2  Female  Gentoo
# 329       4850.0            46.8  Female  Gentoo
# 330       5750.0            50.4    Male  Gentoo
# 331       5200.0            45.2  Female  Gentoo
# 332       5400.0            49.9    Male  Gentoo
#
# [333 rows x 4 columns]

# %%
ols_formula = "body_mass_g ~ bill_length_mm + C(gender) + C(species)"

# %%
X_train = df[["bill_length_mm", "gender", "species"]]
y_train = df[["body_mass_g"]]

# %%
ols_data = pd.concat([X_train, y_train], axis =1)
OLS = ols(formula = ols_formula, data = ols_data)
model = OLS.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            body_mass_g   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                     485.6
# Date:                Thu, 19 Sep 2024   Prob (F-statistic):          2.24e-136
# Time:                        16:08:34   Log-Likelihood:                -2378.0
# No. Observations:                 333   AIC:                             4766.
# Df Residuals:                     328   BIC:                             4785.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **kiểm tra các giả định trong hồi quy tuyến tính đa biến**

# %%
# tính tuyến tính 
sns.pairplot(dfs)

# %%
#tính chuẩn tác
residuals = model.resid
fig, axes = plt.subplots(1,2,figsize=(8,4))
sns.histplot(residuals, ax=axes[0])
axes[0].set_xlabel("asdgfsa")
axes[0].set_title("gyahfgsdhjf")
sm.qqplot(residuals, line='s', ax = axes[1])
axes[1].set_title("hshfs")
plt.tight_layout()
plt.show()

# %%
# tính đồng nhất
fig = sns.scatterplot(x = model.fittedvalues, y = model.resid)
fig.set_xlabel("hgasdgf")
fig.set_ylabel("gvsagdf")
fig.set_title("shgfhs")
fig.axhline(0)
plt.show()

# %%
#tính đa tuyến
dt = dfs[["body_mass_g", "bill_length_mm", "flipper_length_mm"]]
dt.corr(method='pearson')
# Out:
#                    body_mass_g  bill_length_mm  flipper_length_mm
# body_mass_g           1.000000        0.595110           0.871202
# bill_length_mm        0.595110        1.000000           0.656181
# flipper_length_mm     0.871202        0.656181           1.000000

# %%
plt.figure(figsize=(6,4))
sns.heatmap(dt.corr(method='pearson'), annot=True, cmap='Reds')
plt.title('sghadghvas')
plt.show()
